# %% [markdown]
# # 作业：手写数字加法机
#
# 本文件是与集智AI学园出品的系列课程“火炬上的深度学习”配套的作业notebook。本作业要求学员构造一个卷积神经网，输入两张手写数字图片，输出这两个数字的和。
#
# 本文件提供了一个完成做的大框架，学员需要自行修改、添加代码，从而完成任务
#
# 本文件是集智AI学园http://campus.swarma.org 出品的“火炬上的深度学习”第III课的配套源代码

# %%
# 导入所需要的包，请保证torchvision已经在你的环境中安装好
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.optim as optim
import torch.nn.functional as F

import torchvision.datasets as dsets
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
USE_CUDA = torch.cuda.is_available()

# %%
# 定义需要用到的超参数
image_size = 28  #图像的总尺寸28*28
num_classes = 10  #标签的种类数
num_epochs = 20  #训练的总循环周期
batch_size = 64

# 加载MINIST数据，如果没有下载过，就会在当前路径下新建/data子目录，并把文件存放其中

train_dataset = dsets.MNIST(root='./data',  #文件存放路径
                            train=True,   #提取训练集
                            transform=transforms.ToTensor(),  #将图像转化为Tensor
                            download=True)

test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())

# 由于每一个样本需要输入两个图片，因此每一个loader和sampler都有两个

sampler1 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.permutation(range(len(train_dataset))))
sampler2 = torch.utils.data.sampler.SubsetRandomSampler(
    np.random.permutation(range(len(train_dataset))))

# 训练数据的两个加载器
train_loader1 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = False,
                                           sampler = sampler1
                                           )
train_loader2 = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = batch_size,
                                           shuffle = False,
                                           sampler = sampler2
                                           )
#vlueerror: mutually exclussive with shuffle??

# 校验数据和测试数据都各自有两套
val_size = 5000
val_indices1 = range(val_size)
val_indices2 = np.random.permutation(range(val_size))
test_indices1 = range(val_size, len(test_dataset))
test_indices2 = np.random.permutation(test_indices1)
val_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(val_indices1)
val_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(val_indices2)

test_sampler1 = torch.utils.data.sampler.SubsetRandomSampler(test_indices1)
test_sampler2 = torch.utils.data.sampler.SubsetRandomSampler(test_indices2)

val_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler1
                                        )
val_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                        batch_size = batch_size,
                                        shuffle = False,
                                        sampler = val_sampler2
                                        )
test_loader1 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler1
                                         )
test_loader2 = torch.utils.data.DataLoader(dataset = test_dataset,
                                         batch_size = batch_size,
                                         shuffle = False,
                                         sampler = test_sampler2
                                         )

# %% [markdown]
# # MINST Adder

# %% [markdown]
# 为了实现加法器，需要同时处理两个手写体数字图像，并对它进行相应的图像处理
# 因此，网络的架构为两个卷积神经网络，串联上两个全链接层

# %%
depth = [32, 64]
fc = [1024, 32, 1]
class MINSTAdder(nn.Module):
    def __init__(self):
        super(MINSTAdder, self).__init__()
        #公共网络部件
        self.net_pool = nn.MaxPool2d(kernel_size=2, stride=2) # only hyperparameter here
        self.bc1 = nn.BatchNorm1d(num_features=fc[0]) # batch normalization, because of the batch training
        self.bc2 = nn.BatchNorm1d(num_features=fc[1])
        
        #处理第一个图像处理用的卷积网络部件
        self.net1_conv1 = nn.Conv2d(in_channels=1, out_channels=depth[0], kernel_size=5, padding = 2)
        # feature map size is 14*14 by pooling
        # padding=2 for same padding
        self.net1_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) 
        # feature map size is 7*7 by pooling
         
        #处理第二个图像处理用的卷积网络部件
        self.net2_conv1 = nn.Conv2d(in_channels=1, out_channels=depth[0], kernel_size=5, padding = 2)
        # feature map size is 14*14 by pooling
        # padding=2 for same padding
        self.net2_conv2 = nn.Conv2d(depth[0], depth[1], 5, padding = 2) 
        # feature map size is 7*7 by pooling      
        
        #后面的全连阶层
        self.fc1 = nn.Linear(in_features= 2 * depth[1] * (image_size // 4) * (image_size // 4), 
                             out_features=fc[0])
        self.fc2 = nn.Linear(fc[0], fc[1])
        self.fc3 = nn.Linear(fc[1], fc[2])
        
    def forward(self, x, y, training = True):
        #第一张图像的处理流程 
        x = F.relu(self.net1_conv1(x))         # 1*28*28 --> 32*28*28
        x = self.net_pool(x)                   # 32*28*28 --> 32*14*14
        x = F.relu(self.net1_conv2(x))         # 32*14*14 --> 64*14*14
        x = self.net_pool(x)                   # 64*14*14 --> 64*7*7
        x = x.view(-1, depth[1] * (image_size // 4) * (image_size // 4)) # flatten, reshape variable
         
        #第二张图像的处理流程
        y = F.relu(self.net2_conv1(y))         # 1*28*28 --> 32*28*28
        y = self.net_pool(y)                   # 32*28*28 --> 32*14*14
        y = F.relu(self.net2_conv2(y))         # 32*14*14 --> 64*14*14
        y = self.net_pool(y)                   # 64*14*14 --> 64*7*7
        y = y.view(-1, depth[1] * (image_size // 4) * (image_size // 4)) # flatten, reshape variable
         
        #将前两部处理得到的张量并列到一起，喂给两层全链接前馈网络，最后输出预测数值
        z = torch.cat((x, y), 1)                # 2,1024 --> 2048 
        z = F.relu(self.bc1(self.fc1(z)))       # 2048 -->1024
        z = F.dropout(z, p=0.5, training=self.training) #以默认为0.5的概率对这一层进行dropout操作
        z = F.relu(self.bc2(self.fc2(z)))       # 1024 --> 32
        z = F.dropout(z, p=0.2, training=self.training)
        z = F.relu(self.fc3(z))                 # 32 --> 1    
        return z
        

# 计算准确度的函数（有多少数字给出了严格的正确输出结果）
def rightness(y, target):
    out = torch.round(y.view(-1)).type(torch.LongTensor)
    out = out.eq(target).sum()
    out1 = y.size()[0]
    return(out, out1)
net = MINSTAdder()
net
# Out:
# MINSTAdder (
#   (net_pool): MaxPool2d (size=(2, 2), stride=(2, 2), dilation=(1, 1))
#   (bc1): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True)
#   (bc2): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True)
#   (net1_conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (net1_conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (net2_conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (net2_conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (fc1): Linear (6272 -> 1024)
#   (fc2): Linear (1024 -> 32)
#   (fc3): Linear (32 -> 1)
# )

# %%
#将网络定义为一个预测器，来对加法的结果进行预测，因此用MSE平均平房误差作为我们的损失函数
net.cuda()
criterion = nn.MSELoss()
optimizer = optim.SGD(net.parameters(), lr = 0.0001, momentum = 0.9)
results = {}

# %%
# %%time
# 开始训练循环，本部分代码需要补齐
records = []
for epoch in range(num_epochs):
    losses = []
    # 一个关键技术难点是对两个数据加载器进行读取成对儿的数据。我们的办法是通过zip命令，将loader1和2并列在一起，一对一对的读取数据
    for idx, data in enumerate(zip(train_loader1, train_loader2)):
        ((x1, y1), (x2, y2)) = data
        optimizer.zero_grad()
        net.train()
        outputs = net(Variable(x1).cuda(), Variable(x2).cuda())
        labels = y1 + y2
        loss = criterion(outputs, Variable(labels.type(torch.FloatTensor)).cuda())
        loss.backward()
        optimizer.step()
        losses.append(loss.data[0])
#       right = rightness(output, target)
#       losses.append((right[1]-right[0]) / right[1] * 1.0) # (总样例数-正确样例数)/总样例数
        if idx % 100 == 0:
            net.eval()
            val_losses = []
            val_rights = []
            for ((x1,y1),(x2, y2)) in zip(val_loader1,val_loader2):
                out = net(Variable(x1).cuda(), Variable(x2).cuda())
                labels = y1 + y2
                loss = criterion(out, Variable(labels.type(torch.FloatTensor)).cuda())
                val_losses.append(loss.data[0])
                right = rightness(out, Variable(labels))
                val_rights.append(right)
            val_r = (sum([tup[0].data[0] for tup in val_rights]), sum([tup[1] for tup in val_rights]))
#           print(val_r)
            right_ratio = 100.0 * val_r[0] / val_r[1]
            
            #每间隔一定周期就打印一下训练集、校验集的准确率结果
            print('第{}周期，第({}/{})个撮，训练误差：{:.2f}, 校验误差：{:.2f}, 准确率：{:.2f}'.format(
                epoch, idx, len(train_loader1),
                np.mean(losses), np.mean(val_losses), right_ratio))
            records.append([np.mean(losses), np.mean(val_losses), right_ratio])
# Out:
# 第0周期，第(0/938)个撮，训练误差：91.12, 校验误差：97.02, 准确率：0.82
# 第0周期，第(100/938)个撮，训练误差：76.86, 校验误差：39.90, 准确率：2.80
# 第0周期，第(200/938)个撮，训练误差：47.86, 校验误差：8.04, 准确率：12.94
# 第0周期，第(300/938)个撮，训练误差：34.38, 校验误差：4.14, 准确率：21.48
# 第0周期，第(400/938)个撮，训练误差：27.32, 校验误差：3.37, 准确率：24.74
# 第0周期，第(500/938)个撮，训练误差：22.94, 校验误差：3.06, 准确率：26.62
# 第0周期，第(600/938)个撮，训练误差：19.97, 校验误差：3.26, 准确率：26.70
# 第0周期，第(700/938)个撮，训练误差：17.82, 校验误差：3.12, 准确率：27.20
# 第0周期，第(800/938)个撮，训练误差：16.15, 校验误差：2.89, 准确率：28.56
# 第0周期，第(900/938)个撮，训练误差：14.82, 校验误差：2.56, 准确率：30.82
# 第1周期，第(0/938)个撮，训练误差：3.57, 校验误差：3.55, 准确率：23.44
# 第1周期，第(100/938)个撮，训练误差：4.15, 校验误差：2.46, 准确率：30.50
# 第1周期，第(200/938)个撮，训练误差：4.01, 校验误差：2.68, 准确率：29.92
# 第1周期，第(300/938)个撮，训练误差：3.93, 校验误差：2.31, 准确率：33.20
# 第1周期，第(400/938)个撮，训练误差：3.89, 校验误差：2.30, 准确率：33.32
# 第1周期，第(500/938)个撮，训练误差：3.84, 校验误差：2.45, 准确率：30.04
# 第1周期，第(600/938)个撮，训练误差：3.78, 校验误差：3.03, 准确率：25.56
# 第1周期，第(700/938)个撮，训练误差：3.74, 校验误差：2.28, 准确率：32.66
# 第1周期，第(800/938)个撮，训练误差：3.68, 校验误差：2.60, 准确率：29.62
# 第1周期，第(900/938)个撮，训练误差：3.64, 校验误差：1.93, 准确率：35.88
# 第2周期，第(0/938)个撮，训练误差：4.19, 校验误差：1.98, 准确率：36.20
# 第2周期，第(100/938)个撮，训练误差：3.13, 校验误差：1.96, 准确率：36.90
# 第2周期，第(200/938)个撮，训练误差：3.16, 校验误差：1.85, 准确率：37.40
# 第2周期，第(300/938)个撮，训练误差：3.14, 校验误差：2.06, 准确率：36.98
# 第2周期，第(400/938)个撮，训练误差：3.14, 校验误差：2.82, 准确率：26.34
# 第2周期，第(500/938)个撮，训练误差：3.09, 校验误差：1.93, 准确率：36.34
# 第2周期，第(600/938)个撮，训练误差：3.07, 校验误差：2.14, 准确率：34.90
# 第2周期，第(700/938)个撮，训练误差：3.05, 校验误差：2.11, 准确率：33.30
# 第2周期，第(800/938)个撮，训练误差：3.02, 校验误差：2.00, 准确率：35.18
# 第2周期，第(900/938)个撮，训练误差：3.01, 校验误差：1.62, 准确率：41.44
# 第3周期，第(0/938)个撮，训练误差：3.22, 校验误差：1.75, 准确率：40.76
# 第3周期，第(100/938)个撮，训练误差：2.68, 校验误差：1.67, 准确率：40.84
# 第3周期，第(200/938)个撮，训练误差：2.69, 校验误差：1.77, 准确率：41.02
# 第3周期，第(300/938)个撮，训练误差：2.68, 校验误差：1.60, 准确率：40.66
# 第3周期，第(400/938)个撮，训练误差：2.68, 校验误差：1.57, 准确率：42.82
# 第3周期，第(500/938)个撮，训练误差：2.66, 校验误差：1.53, 准确率：43.20
# 第3周期，第(600/938)个撮，训练误差：2.65, 校验误差：1.72, 准确率：39.40
# 第3周期，第(700/938)个撮，训练误差：2.63, 校验误差：1.66, 准确率：40.94
# 第3周期，第(800/938)个撮，训练误差：2.61, 校验误差：1.59, 准确率：43.32
# 第3周期，第(900/938)个撮，训练误差：2.59, 校验误差：1.61, 准确率：43.46
# 第4周期，第(0/938)个撮，训练误差：1.83, 校验误差：1.59, 准确率：41.64
# 第4周期，第(100/938)个撮，训练误差：2.45, 校验误差：1.46, 准确率：46.20
# 第4周期，第(200/938)个撮，训练误差：2.42, 校验误差：1.46, 准确率：44.70
# 第4周期，第(300/938)个撮，训练误差：2.43, 校验误差：1.69, 准确率：41.06
# 第4周期，第(400/938)个撮，训练误差：2.41, 校验误差：1.47, 准确率：44.40
# 第4周期，第(500/938)个撮，训练误差：2.43, 校验误差：1.46, 准确率：44.76
# 第4周期，第(600/938)个撮，训练误差：2.40, 校验误差：1.60, 准确率：41.62
# 第4周期，第(700/938)个撮，训练误差：2.39, 校验误差：1.36, 准确率：47.72
# 第4周期，第(800/938)个撮，训练误差：2.38, 校验误差：1.34, 准确率：47.42
# 第4周期，第(900/938)个撮，训练误差：2.36, 校验误差：1.39, 准确率：47.50
# 第5周期，第(0/938)个撮，训练误差：3.36, 校验误差：1.62, 准确率：40.48
# 第5周期，第(100/938)个撮，训练误差：2.23, 校验误差：1.38, 准确率：46.42
# 第5周期，第(200/938)个撮，训练误差：2.23, 校验误差：1.36, 准确率：48.08
# 第5周期，第(300/938)个撮，训练误差：2.22, 校验误差：1.31, 准确率：48.70
# 第5周期，第(400/938)个撮，训练误差：2.21, 校验误差：1.31, 准确率：47.90
# 第5周期，第(500/938)个撮，训练误差：2.19, 校验误差：1.42, 准确率：45.28
# 第5周期，第(600/938)个撮，训练误差：2.19, 校验误差：1.24, 准确率：49.86
# 第5周期，第(700/938)个撮，训练误差：2.20, 校验误差：1.26, 准确率：49.40
# 第5周期，第(800/938)个撮，训练误差：2.21, 校验误差：1.32, 准确率：49.06
# 第5周期，第(900/938)个撮，训练误差：2.20, 校验误差：1.52, 准确率：42.38
# 第6周期，第(0/938)个撮，训练误差：1.77, 校验误差：1.21, 准确率：49.82
# 第6周期，第(100/938)个撮，训练误差：2.08, 校验误差：1.29, 准确率：48.34
# 第6周期，第(200/938)个撮，训练误差：2.07, 校验误差：1.29, 准确率：48.84
# 第6周期，第(300/938)个撮，训练误差：2.09, 校验误差：1.38, 准确率：47.18
# 第6周期，第(400/938)个撮，训练误差：2.07, 校验误差：1.32, 准确率：47.04
# 第6周期，第(500/938)个撮，训练误差：2.05, 校验误差：1.32, 准确率：48.04
# 第6周期，第(600/938)个撮，训练误差：2.05, 校验误差：1.23, 准确率：51.48
# 第6周期，第(700/938)个撮，训练误差：2.05, 校验误差：1.18, 准确率：51.20
# 第6周期，第(800/938)个撮，训练误差：2.05, 校验误差：1.28, 准确率：50.06
# 第6周期，第(900/938)个撮，训练误差：2.04, 校验误差：1.18, 准确率：52.10
# 第7周期，第(0/938)个撮，训练误差：1.72, 校验误差：1.44, 准确率：43.84
# 第7周期，第(100/938)个撮，训练误差：1.99, 校验误差：1.32, 准确率：49.22
# 第7周期，第(200/938)个撮，训练误差：1.97, 校验误差：1.15, 准确率：50.72
# 第7周期，第(300/938)个撮，训练误差：1.98, 校验误差：1.12, 准确率：52.36
# 第7周期，第(400/938)个撮，训练误差：1.99, 校验误差：1.32, 准确率：48.34
# 第7周期，第(500/938)个撮，训练误差：1.97, 校验误差：1.21, 准确率：50.58
# 第7周期，第(600/938)个撮，训练误差：1.96, 校验误差：1.11, 准确率：52.78
# 第7周期，第(700/938)个撮，训练误差：1.95, 校验误差：1.17, 准确率：50.34
# 第7周期，第(800/938)个撮，训练误差：1.95, 校验误差：1.16, 准确率：52.40
# 第7周期，第(900/938)个撮，训练误差：1.94, 校验误差：1.10, 准确率：52.56
# 第8周期，第(0/938)个撮，训练误差：1.31, 校验误差：1.11, 准确率：53.86
# 第8周期，第(100/938)个撮，训练误差：1.94, 校验误差：1.34, 准确率：48.64
# 第8周期，第(200/938)个撮，训练误差：1.85, 校验误差：1.14, 准确率：53.30
# 第8周期，第(300/938)个撮，训练误差：1.82, 校验误差：1.13, 准确率：53.26
# 第8周期，第(400/938)个撮，训练误差：1.84, 校验误差：1.03, 准确率：54.70
# 第8周期，第(500/938)个撮，训练误差：1.83, 校验误差：1.07, 准确率：55.40
# 第8周期，第(600/938)个撮，训练误差：1.84, 校验误差：1.18, 准确率：51.14
# 第8周期，第(700/938)个撮，训练误差：1.84, 校验误差：1.06, 准确率：55.34
# 第8周期，第(800/938)个撮，训练误差：1.83, 校验误差：1.11, 准确率：51.68
# 第8周期，第(900/938)个撮，训练误差：1.83, 校验误差：1.15, 准确率：50.36
# 第9周期，第(0/938)个撮，训练误差：2.00, 校验误差：1.10, 准确率：53.24
# 第9周期，第(100/938)个撮，训练误差：1.71, 校验误差：1.03, 准确率：55.04
# 第9周期，第(200/938)个撮，训练误差：1.76, 校验误差：1.13, 准确率：51.98
# 第9周期，第(300/938)个撮，训练误差：1.76, 校验误差：1.07, 准确率：55.38
# 第9周期，第(400/938)个撮，训练误差：1.78, 校验误差：1.09, 准确率：53.44
# 第9周期，第(500/938)个撮，训练误差：1.80, 校验误差：1.08, 准确率：54.24
# 第9周期，第(600/938)个撮，训练误差：1.80, 校验误差：1.12, 准确率：51.82
# 第9周期，第(700/938)个撮，训练误差：1.78, 校验误差：1.13, 准确率：50.78
# 第9周期，第(800/938)个撮，训练误差：1.78, 校验误差：1.01, 准确率：55.66
# 第9周期，第(900/938)个撮，训练误差：1.78, 校验误差：0.97, 准确率：56.62
# 第10周期，第(0/938)个撮，训练误差：1.39, 校验误差：0.94, 准确率：56.72
# 第10周期，第(100/938)个撮，训练误差：1.62, 校验误差：1.01, 准确率：56.10
# 第10周期，第(200/938)个撮，训练误差：1.66, 校验误差：0.97, 准确率：56.78
# 第10周期，第(300/938)个撮，训练误差：1.66, 校验误差：0.98, 准确率：57.48
# 第10周期，第(400/938)个撮，训练误差：1.68, 校验误差：0.97, 准确率：57.20
# 第10周期，第(500/938)个撮，训练误差：1.70, 校验误差：1.06, 准确率：54.12
# 第10周期，第(600/938)个撮，训练误差：1.70, 校验误差：1.15, 准确率：53.28
# 第10周期，第(700/938)个撮，训练误差：1.70, 校验误差：1.01, 准确率：55.84
# 第10周期，第(800/938)个撮，训练误差：1.69, 校验误差：0.94, 准确率：57.72
# 第10周期，第(900/938)个撮，训练误差：1.69, 校验误差：1.05, 准确率：57.06
# 第11周期，第(0/938)个撮，训练误差：2.08, 校验误差：0.96, 准确率：57.42
# 第11周期，第(100/938)个撮，训练误差：1.65, 校验误差：1.03, 准确率：55.80
# 第11周期，第(200/938)个撮，训练误差：1.66, 校验误差：0.99, 准确率：58.10
# 第11周期，第(300/938)个撮，训练误差：1.68, 校验误差：0.93, 准确率：59.12
# 第11周期，第(400/938)个撮，训练误差：1.68, 校验误差：0.91, 准确率：58.62
# 第11周期，第(500/938)个撮，训练误差：1.67, 校验误差：0.94, 准确率：58.56
# 第11周期，第(600/938)个撮，训练误差：1.67, 校验误差：0.92, 准确率：58.58
# 第11周期，第(700/938)个撮，训练误差：1.67, 校验误差：0.95, 准确率：58.92
# 第11周期，第(800/938)个撮，训练误差：1.67, 校验误差：1.03, 准确率：55.84
# 第11周期，第(900/938)个撮，训练误差：1.67, 校验误差：1.21, 准确率：50.96
# 第12周期，第(0/938)个撮，训练误差：1.92, 校验误差：0.92, 准确率：58.04
# 第12周期，第(100/938)个撮，训练误差：1.62, 校验误差：1.04, 准确率：56.84
# 第12周期，第(200/938)个撮，训练误差：1.61, 校验误差：0.94, 准确率：58.66
# 第12周期，第(300/938)个撮，训练误差：1.61, 校验误差：0.95, 准确率：56.78
# 第12周期，第(400/938)个撮，训练误差：1.59, 校验误差：0.87, 准确率：60.54
# 第12周期，第(500/938)个撮，训练误差：1.58, 校验误差：0.95, 准确率：58.78
# 第12周期，第(600/938)个撮，训练误差：1.58, 校验误差：1.03, 准确率：56.60
# 第12周期，第(700/938)个撮，训练误差：1.57, 校验误差：0.96, 准确率：60.04
# 第12周期，第(800/938)个撮，训练误差：1.57, 校验误差：0.98, 准确率：57.56
# 第12周期，第(900/938)个撮，训练误差：1.57, 校验误差：0.87, 准确率：59.98
# 第13周期，第(0/938)个撮，训练误差：1.28, 校验误差：0.89, 准确率：60.42
# 第13周期，第(100/938)个撮，训练误差：1.49, 校验误差：1.01, 准确率：56.92
# 第13周期，第(200/938)个撮，训练误差：1.54, 校验误差：0.96, 准确率：57.18
# 第13周期，第(300/938)个撮，训练误差：1.54, 校验误差：1.08, 准确率：54.70
# 第13周期，第(400/938)个撮，训练误差：1.56, 校验误差：0.89, 准确率：60.94
# 第13周期，第(500/938)个撮，训练误差：1.54, 校验误差：0.92, 准确率：56.58
# 第13周期，第(600/938)个撮，训练误差：1.56, 校验误差：1.01, 准确率：56.98
# 第13周期，第(700/938)个撮，训练误差：1.56, 校验误差：0.98, 准确率：57.76
# 第13周期，第(800/938)个撮，训练误差：1.56, 校验误差：0.93, 准确率：59.82
# 第13周期，第(900/938)个撮，训练误差：1.54, 校验误差：0.88, 准确率：61.76
# 第14周期，第(0/938)个撮，训练误差：1.31, 校验误差：0.91, 准确率：59.62
# 第14周期，第(100/938)个撮，训练误差：1.49, 校验误差：0.84, 准确率：61.46
# 第14周期，第(200/938)个撮，训练误差：1.53, 校验误差：1.00, 准确率：57.16
# 第14周期，第(300/938)个撮，训练误差：1.53, 校验误差：0.85, 准确率：60.70
# 第14周期，第(400/938)个撮，训练误差：1.54, 校验误差：1.05, 准确率：55.28
# 第14周期，第(500/938)个撮，训练误差：1.53, 校验误差：0.85, 准确率：62.14
# 第14周期，第(600/938)个撮，训练误差：1.53, 校验误差：0.91, 准确率：59.84
# 第14周期，第(700/938)个撮，训练误差：1.52, 校验误差：0.92, 准确率：59.30
# 第14周期，第(800/938)个撮，训练误差：1.52, 校验误差：0.89, 准确率：60.46
# 第14周期，第(900/938)个撮，训练误差：1.51, 校验误差：0.83, 准确率：61.54
# 第15周期，第(0/938)个撮，训练误差：1.17, 校验误差：0.84, 准确率：61.74
# 第15周期，第(100/938)个撮，训练误差：1.46, 校验误差：0.89, 准确率：60.48
# 第15周期，第(200/938)个撮，训练误差：1.50, 校验误差：0.82, 准确率：64.04
# 第15周期，第(300/938)个撮，训练误差：1.49, 校验误差：0.89, 准确率：60.12
# 第15周期，第(400/938)个撮，训练误差：1.48, 校验误差：0.79, 准确率：62.32
# 第15周期，第(500/938)个撮，训练误差：1.49, 校验误差：0.88, 准确率：60.76
# 第15周期，第(600/938)个撮，训练误差：1.48, 校验误差：0.85, 准确率：61.32
# 第15周期，第(700/938)个撮，训练误差：1.47, 校验误差：0.93, 准确率：57.40
# 第15周期，第(800/938)个撮，训练误差：1.47, 校验误差：0.84, 准确率：61.36
# 第15周期，第(900/938)个撮，训练误差：1.47, 校验误差：0.84, 准确率：61.62
# 第16周期，第(0/938)个撮，训练误差：1.20, 校验误差：0.90, 准确率：61.80
# 第16周期，第(100/938)个撮，训练误差：1.42, 校验误差：0.85, 准确率：63.34
# 第16周期，第(200/938)个撮，训练误差：1.42, 校验误差：0.91, 准确率：61.00
# 第16周期，第(300/938)个撮，训练误差：1.44, 校验误差：0.84, 准确率：60.00
# 第16周期，第(400/938)个撮，训练误差：1.44, 校验误差：0.81, 准确率：62.22
# 第16周期，第(500/938)个撮，训练误差：1.41, 校验误差：0.85, 准确率：61.82
# 第16周期，第(600/938)个撮，训练误差：1.41, 校验误差：0.82, 准确率：62.12
# 第16周期，第(700/938)个撮，训练误差：1.41, 校验误差：0.79, 准确率：61.96
# 第16周期，第(800/938)个撮，训练误差：1.41, 校验误差：0.81, 准确率：63.84
# 第16周期，第(900/938)个撮，训练误差：1.41, 校验误差：0.86, 准确率：61.54
# 第17周期，第(0/938)个撮，训练误差：1.65, 校验误差：0.79, 准确率：63.52
# 第17周期，第(100/938)个撮，训练误差：1.32, 校验误差：0.79, 准确率：63.24
# 第17周期，第(200/938)个撮，训练误差：1.35, 校验误差：0.84, 准确率：63.34
# 第17周期，第(300/938)个撮，训练误差：1.38, 校验误差：0.76, 准确率：64.38
# 第17周期，第(400/938)个撮，训练误差：1.40, 校验误差：0.78, 准确率：64.40
# 第17周期，第(500/938)个撮，训练误差：1.41, 校验误差：0.81, 准确率：64.74
# 第17周期，第(600/938)个撮，训练误差：1.41, 校验误差：0.81, 准确率：63.36
# 第17周期，第(700/938)个撮，训练误差：1.42, 校验误差：0.80, 准确率：65.12
# 第17周期，第(800/938)个撮，训练误差：1.42, 校验误差：0.80, 准确率：64.46
# 第17周期，第(900/938)个撮，训练误差：1.41, 校验误差：0.79, 准确率：63.52
# 第18周期，第(0/938)个撮，训练误差：1.45, 校验误差：0.84, 准确率：59.96
# 第18周期，第(100/938)个撮，训练误差：1.39, 校验误差：0.77, 准确率：63.26
# 第18周期，第(200/938)个撮，训练误差：1.35, 校验误差：0.84, 准确率：63.14
# 第18周期，第(300/938)个撮，训练误差：1.37, 校验误差：0.77, 准确率：64.20
# 第18周期，第(400/938)个撮，训练误差：1.38, 校验误差：0.84, 准确率：60.82
# 第18周期，第(500/938)个撮，训练误差：1.38, 校验误差：0.81, 准确率：64.58
# 第18周期，第(600/938)个撮，训练误差：1.39, 校验误差：0.73, 准确率：63.82
# 第18周期，第(700/938)个撮，训练误差：1.39, 校验误差：0.74, 准确率：64.98
# 第18周期，第(800/938)个撮，训练误差：1.39, 校验误差：0.76, 准确率：64.74
# 第18周期，第(900/938)个撮，训练误差：1.38, 校验误差：0.81, 准确率：64.08
# 第19周期，第(0/938)个撮，训练误差：0.77, 校验误差：0.79, 准确率：64.84
# 第19周期，第(100/938)个撮，训练误差：1.41, 校验误差：0.77, 准确率：64.94
# 第19周期，第(200/938)个撮，训练误差：1.39, 校验误差：0.77, 准确率：64.64
# 第19周期，第(300/938)个撮，训练误差：1.38, 校验误差：0.76, 准确率：65.14
# 第19周期，第(400/938)个撮，训练误差：1.38, 校验误差：0.83, 准确率：60.86
# 第19周期，第(500/938)个撮，训练误差：1.38, 校验误差：0.87, 准确率：61.12
# 第19周期，第(600/938)个撮，训练误差：1.37, 校验误差：0.75, 准确率：63.26
# 第19周期，第(700/938)个撮，训练误差：1.37, 校验误差：0.77, 准确率：65.20
# 第19周期，第(800/938)个撮，训练误差：1.37, 校验误差：0.77, 准确率：65.46
# 第19周期，第(900/938)个撮，训练误差：1.37, 校验误差：0.79, 准确率：63.74
# CPU times: user 6min 34s, sys: 17.1 s, total: 6min 51s
# Wall time: 6min 51s

# %%
# 在测试集上运行我们的加法机网络，并测试预测准确度
torch.save(net, 'net_adder.pkl')
# 在测试集上运行我们的加法机网络，并测试预测准确度
net.eval()
vals = []
for ((x1,y1),(x2, y2)) in zip(test_loader1,test_loader2):
    net.cpu()
    out = net(Variable(x1), Variable(x2))
    label = y1 + y2
    right = rightness(out, Variable(label))
    vals.append(right)
    
#计算准确率
val_r = (sum([tup[0].data[0] for tup in vals]), sum([tup[1] for tup in vals]))
right_rate = 1.0 * val_r[0] / val_r[1]
right_rate
# Out:
# /home/ken/anaconda3/envs/tf12/lib/python3.6/site-packages/torch/serialization.py:147: UserWarning: Couldn't retrieve source code for container of type MINSTAdder. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# 0.7546
